# %%
#Mayelin Stefania Aguilar Vásquez
#Marzo 19, 2023

# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("DNP-ProductoSector.csv")

#Mostrando encabezado

df.head()
# Out:
#                               Sector     UnidadMedidaProducto  \
# 0                           Interior                   Número
# 1  Inclusión Social Y Reconciliación       Número de personas
# 2     Agricultura Y Desarrollo Rural                      Mes
# 3  Inclusión Social Y Reconciliación  Número de beneficiarios
# 4                            Cultura       Número de usuarios
#
#                                            Indicador    UnidadMedidaIndicador  \
# 0  Asesorías técnicas realizadas Actualizadas par...                   Número
# 1  Personas vinculadas a empleo formal para pobla...       Número de personas
# 2          Cadenas productivas apoyadas con recursos                      Mes
# 3  Beneficiarios potenciales para quienes se gest...  Número de beneficiarios
# 4                                           Usuarios       Número de usuarios
#
#                                             Producto  Cantidad  MetaIndicador  \
# ...

# %%
#Tamanño tabla:
df.shape
# Out:
# (372031, 9)

# %%
# Identificando los sectores para evaluar la distribución de inversión:
df.columns
# Out:
# Index(['Sector', 'UnidadMedidaProducto', 'Indicador', 'UnidadMedidaIndicador',
#        'Producto', 'Cantidad', 'MetaIndicador', 'AvanceIndicador',
#        'ValorProducto'],
#       dtype='object')

# %%
# Identificando los sectores tipo de varibles en la tabla:
df.dtypes
# Out:
# Sector                    object
# UnidadMedidaProducto      object
# Indicador                 object
# UnidadMedidaIndicador     object
# Producto                  object
# Cantidad                 float64
# MetaIndicador            float64
# AvanceIndicador          float64
# ValorProducto            float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 372031 entries, 0 to 372030
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Sector                 372031 non-null  object
#  1   UnidadMedidaProducto   372009 non-null  object
#  2   Indicador              372021 non-null  object
#  3   UnidadMedidaIndicador  372010 non-null  object
#  4   Producto               372030 non-null  object
#  5   Cantidad               372031 non-null  float64
#  6   MetaIndicador          372031 non-null  float64
#  7   AvanceIndicador        372031 non-null  float64
#  8   ValorProducto          371823 non-null  float64
# dtypes: float64(4), object(5)
# memory usage: 25.5+ MB

# %%
df.isnull().sum()
# Out:
# Sector                     0
# UnidadMedidaProducto      22
# Indicador                 10
# UnidadMedidaIndicador     21
# Producto                   1
# Cantidad                   0
# MetaIndicador              0
# AvanceIndicador            0
# ValorProducto            208
# dtype: int64

# %%
#Estudiar seis de casos de sectores para en inversión, que se cree como los sectores fundamentales para analizar la pobreza en Colombia
df['Sector'].unique()
# Out:
# array(['Interior', 'Inclusión Social Y Reconciliación',
#        'Agricultura Y Desarrollo Rural', 'Cultura', 'Educación',
#        'Deporte Y Recreación', 'Ambiente Y Desarrollo Sostenible',
#        'Transporte', 'Vivienda Ciudad Y Territorio',
#        'Gobierno Territorial', 'Salud Y Protección Social',
#        'Ciencia Tecnología E Innovación', 'Planeación', 'Minas Y Energía',
#        'Trabajo', 'Comercio Industria Y Turismo',
#        'Presidencia De La República', 'Empleo Público',
#        'Justicia Y Del Derecho', 'Información Estadística', 'Hacienda',
#        'Tecnologías De La Información Y Las Comunicaciones',
#        'Organismos De Control', 'Fiscalía', 'Rama Judicial',
#        'Registraduría', 'Congreso De La República',
#        'Relaciones Exteriores',
#        'Sistema Integral De Verdad Justicia Reparación Y No Repetición'],
#       dtype=object)

# %%
#Por cada sector se evalúa cuanta inversión hay con valor producto
df.head(372031)
# Out:
#                                    Sector  \
# 0                                Interior
# 1       Inclusión Social Y Reconciliación
# 2          Agricultura Y Desarrollo Rural
# 3       Inclusión Social Y Reconciliación
# 4                                 Cultura
# ...                                   ...
# 372026  Inclusión Social Y Reconciliación
# 372027       Comercio Industria Y Turismo
# 372028               Deporte Y Recreación
# 372029                          Educación
# 372030  Inclusión Social Y Reconciliación
#
#                                   UnidadMedidaProducto  \
# 0                                               Número
# 1                                   Número de personas
# 2                                                  Mes
# 3                              Número de beneficiarios
# 4                                   Número de usuarios
# ...                                                ...
# 372026                               Número de centros
# ...

# %%
#Evaluando la inversión en cada sector, con la columna Valor Producto, aunque no es clara la informaciòn proporcionada por el gráfico

fig, ax = plt.subplots(nrows=1, ncols=1,figsize=(30, 15))
ax.plot(x, y, label='Inversión DNP',color='r')
ax.plot(x, y-800, label='Pr',color='b')
ax.set_xlabel('Sector')                  
ax.set_ylabel('Valor Producto')
ax.set_title('')
ax.legend(loc='upper left')

# %%
sector_data = df.select_dtypes(include='number').columns
df[sector_data].sum(axis='rows')
# Out:
# Cantidad           3.559781e+13
# MetaIndicador      3.536744e+13
# AvanceIndicador    2.491171e+13
# ValorProducto      1.800687e+15
# dtype: float64

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[386], line 1
# ----> 1 sector_data.index = df['Sector']
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py:5588, in NDFrame.__setattr__(self, name, value)
#    5586 try:
#    5587     object.__getattribute__(self, name)
# -> 5588     return object.__setattr__(self, name, value)
#    5589 except AttributeError:
#    5590     pass
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/_libs/properties.pyx:70, in pandas._libs.properties.AxisProperty.__set__()
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/series.py:572, in Series._set_axis(self, axis, labels, fastpath)
#     568             pass
#     570 if not fastpath:
#     571     # The ensure_index call above ensures we have an Index object
# --> 572     self._mgr.set_axis(axis, labels)
#
# ...

# %%
#Se empieza por el ministerior del Interior, ya que se encarga de la participación ciudadana, orden territorial, asuntos políticos y legislativos ya que tiene
#una estrecha relación con el Congreso y los partidos políticos

df[df["Sector"]=='Interior'].head(300)
# Out:
#             Sector               UnidadMedidaProducto  \
# Sector
# Interior  Interior                             Número
# Interior  Interior              Número de iniciativas
# Interior  Interior   Número de estaciones de bomberos
# Interior  Interior                  Número de eventos
# Interior  Interior                             Unidad
# ...            ...                                ...
# Interior  Interior     Número de cámaras de seguridad
# Interior  Interior               Número de documentos
# Interior  Interior  Número de entidades territoriales
# Interior  Interior      Número de cuerpos de bomberos
# Interior  Interior              Número de iniciativas
#
#                                                   Indicador  \
# Sector
# Interior  Asesorías técnicas realizadas Actualizadas par...
# Interior  Iniciativas de las organizaciones sociales com...
# Interior           Estaciones de bomberos con mantenimiento
# ...

# %%
#Luego se continua con el sector Educación: Que es la parte fundamental del pueblo para capacitarse sea para nuevos emprendimientos o mano de obra calificada para el trabajo

df[df["Sector"]=='Educación'].head(300)
# Out:
#               Sector     UnidadMedidaProducto  \
# Sector
# Educación  Educación  Número de beneficiarios
# Educación  Educación                   Número
# Educación  Educación      Número de entidades
# Educación  Educación     Número de documentos
# Educación  Educación  Número de beneficiarios
# ...              ...                      ...
# Educación  Educación       Número de personas
# Educación  Educación          Número de sedes
# Educación  Educación  Número de beneficiarios
# Educación  Educación       Número de raciones
# Educación  Educación       Número de personas
#
#                                                    Indicador  \
# Sector
# Educación                Beneficiarios de transporte escolar
# Educación                           Estudiantes beneficiados
# Educación  Entidades territoriales con estrategias para l...
# Educación                Documentos de planeación realizados
# Educación                Beneficiarios de transporte escolar
# ...

# %%
#Para el Sector Ciencia y Tecnologìa es fundamental para el desarrollo de nuevas tecnologías que fomente el desarrollo industrial en Colombia

df[df["Sector"]=='Ciencia Tecnología E Innovación'].head(300)
# Out:
#                                                           Sector  \
# Sector
# Ciencia Tecnología E Innovación  Ciencia Tecnología E Innovación
# Ciencia Tecnología E Innovación  Ciencia Tecnología E Innovación
# Ciencia Tecnología E Innovación  Ciencia Tecnología E Innovación
# Ciencia Tecnología E Innovación  Ciencia Tecnología E Innovación
# Ciencia Tecnología E Innovación  Ciencia Tecnología E Innovación
# ...                                                          ...
# Ciencia Tecnología E Innovación  Ciencia Tecnología E Innovación
# Ciencia Tecnología E Innovación  Ciencia Tecnología E Innovación
# Ciencia Tecnología E Innovación  Ciencia Tecnología E Innovación
# Ciencia Tecnología E Innovación  Ciencia Tecnología E Innovación
# Ciencia Tecnología E Innovación  Ciencia Tecnología E Innovación
#
#                                                               UnidadMedidaProducto  \
# Sector
# Ciencia Tecnología E Innovación                                Número de artículos
# ...

# %%
df.to_csv('CyT.csv', sep = ',')

# %%
#El sector Inclusión Social Y Reconciliación se encarga de incluir y mejorar la calidad de vida de personas que están en condiciones de vulnerabilidad y apoyar la garantía
#progresiva del derecho humano a la alimentación y permitir que familias vulnerables y victimas del conflicto tengas medidas de asistencia, atención y reparación otorgadas por el Estado 

df[df["Sector"]=='Inclusión Social Y Reconciliación'].head(300)
# Out:
#                                                               Sector  \
# Sector
# Inclusión Social Y Reconciliación  Inclusión Social Y Reconciliación
# Inclusión Social Y Reconciliación  Inclusión Social Y Reconciliación
# Inclusión Social Y Reconciliación  Inclusión Social Y Reconciliación
# Inclusión Social Y Reconciliación  Inclusión Social Y Reconciliación
# Inclusión Social Y Reconciliación  Inclusión Social Y Reconciliación
# ...                                                              ...
# Inclusión Social Y Reconciliación  Inclusión Social Y Reconciliación
# Inclusión Social Y Reconciliación  Inclusión Social Y Reconciliación
# Inclusión Social Y Reconciliación  Inclusión Social Y Reconciliación
# Inclusión Social Y Reconciliación  Inclusión Social Y Reconciliación
# Inclusión Social Y Reconciliación  Inclusión Social Y Reconciliación
#
#                                                     UnidadMedidaProducto  \
# Sector
# ...

# %%
df.to_csv('Inclusión Social Y Reconciliación.csv', sep = ',')

# %%
# La salud es fundamnetal para cualquier individuo, ya que determina las normas y directrices en salud pública, asistencia social, población en riesgo y pobreza
# (Sf.(7 Marzo 23). Ministerio de Salud y Protección Social. Recuperado de: https://es.wikipedia.org/wiki/Ministerio_de_Salud_y_Protecci%C3%B3n_Social)

df[df["Sector"]=='Salud Y Protección Social'].head(300)
# Out:
#                                               Sector     UnidadMedidaProducto  \
# Sector
# Salud Y Protección Social  Salud Y Protección Social    Número de estrategias
# Salud Y Protección Social  Salud Y Protección Social    Número de cementerios
# Salud Y Protección Social  Salud Y Protección Social        Número de visitas
# Salud Y Protección Social  Salud Y Protección Social  Número de departamentos
# Salud Y Protección Social  Salud Y Protección Social                   Número
# ...                                              ...                      ...
# Salud Y Protección Social  Salud Y Protección Social       Número de informes
# Salud Y Protección Social  Salud Y Protección Social       Número de personas
# Salud Y Protección Social  Salud Y Protección Social                   Unidad
# Salud Y Protección Social  Salud Y Protección Social       Número de campañas
# Salud Y Protección Social  Salud Y Protección Social        Número de visitas
#
# ...

# %%
df.to_csv('Salud Y Protección Social.csv', sep = ',')

# %%
#Sector trabajo es otro de los pilares fundamentales, para evaluar la crisis económica en Colombia, ya que una población sin ingresos, es una población con poco consumo
#generando un ciclo repetitivo, entre oferta y demanda de mercado. (Sf.(2 May 2022). Empleo y desigualdad. El Espectador. Recuperado de: https://www.elespectador.com/opinion/columnistas/re-imaginemos/empleo-y-desigualdad/)

df[df["Sector"]=='Trabajo'].head(300)
# Out:
#           Sector        UnidadMedidaProducto  \
# Sector
# Trabajo  Trabajo         Número de subsidios
# Trabajo  Trabajo                      Número
# Trabajo  Trabajo        Número de documentos
# Trabajo  Trabajo                      Número
# Trabajo  Trabajo          Número de personas
# ...          ...                         ...
# Trabajo  Trabajo           Número de modelos
# Trabajo  Trabajo          Número de acciones
# Trabajo  Trabajo                      Unidad
# Trabajo  Trabajo  Número de planesde negocio
# Trabajo  Trabajo                      Número
#
#                                                  Indicador  \
# Sector
# Trabajo   Subsidios del Programa Colombia Mayor entregados
# Trabajo                             NORMOGRAMA Actualizado
# Trabajo      Documentos de lineamiento técnicos realizados
# Trabajo                              Personas beneficiadas
# Trabajo                    Personas asistidas técnicamente
# ...

# %%
df.to_csv('Trabao.csv', sep = ',')
